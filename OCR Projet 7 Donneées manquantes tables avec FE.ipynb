# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # données manquantes pour la table train

# %%
df_train_FE= pd.DataFrame(pd.read_csv('C:/Users/kalin/df_train_FE.csv'))

# %%
df_train_FE
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 252128      252128      456248       0            1             0
# 252129      252129      456251       0            0             0
# 252130      252130      456253       0            1             0
# 252131      252131      456254       1            1             0
# 252132      252132      456255       0            1             0
#
#         FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0       -9461           -637            -3648.0
# ...

# %%
# pourcentage de données manquantes de chaque variables :

count = df_train_FE.isnull().sum().sort_values(ascending=False)
percentage = ((df_train_FE.isnull().sum()/len(df_train_FE)*100)).sort_values(ascending=False)
missing_df_train_FE = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing_df_train_FE
# Out:
# Count and percentage of missing values s:
#                                       Count  Percentage
# CC_MONTHS_BALANCE_VAR                252133  100.000000
# REFUSED_APP_CREDIT_PERC_VAR          211607   83.926737
# CC_MONTHS_BALANCE_MIN                207906   82.458861
# CC_MONTHS_BALANCE_MAX                207906   82.458861
# CC_MONTHS_BALANCE_MEAN               207906   82.458861
# ...                                     ...         ...
# WEEKDAY_APPR_PROCESS_START_THURSDAY       0    0.000000
# WEEKDAY_APPR_PROCESS_START_SUNDAY         0    0.000000
# WEEKDAY_APPR_PROCESS_START_SATURDAY       0    0.000000
# WEEKDAY_APPR_PROCESS_START_MONDAY         0    0.000000
# Unnamed: 0                                0    0.000000
#
# [727 rows x 2 columns]

# %% [markdown]
# pas plus de 70% de données manquantes par ligne , on n'enlève pas de ligne car le seuil est à 90%

# %%
DM_ligne = pd.DataFrame(df_train_FE.isnull().sum(axis=1))
DM_ligne
# Out:
#           0
# 0       172
# 1       189
# 2       211
# 3       109
# 4       211
# ...     ...
# 252128  135
# 252129  279
# 252130  170
# 252131  405
# 252132  146
#
# [252133 rows x 1 columns]

# %%
DM_ligne_inf90 = DM_ligne[DM_ligne[0]<581]
DM_ligne_inf90
# Out:
#           0
# 0       172
# 1       189
# 2       211
# 3       109
# 4       211
# ...     ...
# 252128  135
# 252129  279
# 252130  170
# 252131  405
# 252132  146
#
# [252133 rows x 1 columns]

# %%
# On garde les variables avec moins de 10% de DM
# variables ayant moins de 10% de DM

missing_final_sup10=missing_df_train_FE[ missing_df_train_FE['Percentage'] >10]
missing_final_sup10
# Out:
#                               Count  Percentage
# CC_MONTHS_BALANCE_VAR        252133  100.000000
# REFUSED_APP_CREDIT_PERC_VAR  211607   83.926737
# CC_MONTHS_BALANCE_MIN        207906   82.458861
# CC_MONTHS_BALANCE_MAX        207906   82.458861
# CC_MONTHS_BALANCE_MEAN       207906   82.458861
# ...                             ...         ...
# APPROVED_AMT_ANNUITY_MAX      32351   12.830927
# APPROVED_AMT_ANNUITY_MIN      32351   12.830927
# PREV_APP_CREDIT_PERC_MEAN     27949   11.085023
# PREV_APP_CREDIT_PERC_MIN      27949   11.085023
# PREV_APP_CREDIT_PERC_MAX      27949   11.085023
#
# [305 rows x 2 columns]

# %%
# supression des variables qui ont plus de 10% de données manquantes 

missing_final_inf10 = df_train_FE.drop(columns=missing_final_sup10.index.tolist())
missing_final_inf10
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 252128      252128      456248       0            1             0
# 252129      252129      456251       0            0             0
# 252130      252130      456253       0            1             0
# 252131      252131      456254       1            1             0
# 252132      252132      456255       0            1             0
#
#         FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0       -9461           -637            -3648.0
# ...

# %%
count = missing_final_inf10.isnull().sum().sort_values(ascending=False)
percentage = ((missing_final_inf10.isnull().sum()/len(missing_final_inf10)*100)).sort_values(ascending=False)
missing_final_inf10_2 = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing_final_inf10_2
# Out:
# Count and percentage of missing values s:
#                                                Count  Percentage
# PREV_HOUR_APPR_PROCESS_START_MEAN              24162    9.583038
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN  24162    9.583038
# PREV_NAME_TYPE_SUITE_Family_MEAN               24162    9.583038
# PREV_NAME_TYPE_SUITE_Children_MEAN             24162    9.583038
# PREV_CODE_REJECT_REASON_nan_MEAN               24162    9.583038
# ...                                              ...         ...
# WEEKDAY_APPR_PROCESS_START_THURSDAY                0    0.000000
# WEEKDAY_APPR_PROCESS_START_SUNDAY                  0    0.000000
# WEEKDAY_APPR_PROCESS_START_SATURDAY                0    0.000000
# WEEKDAY_APPR_PROCESS_START_MONDAY                  0    0.000000
# Unnamed: 0                                         0    0.000000
#
# [422 rows x 2 columns]

# %%
#Table avec variables avec DM <10%

missing_final_inf10_sup0 =missing_final_inf10_2[ missing_final_inf10_2['Percentage'] >1]
missing_final_inf10_sup0
# Out:
#                                                Count  Percentage
# PREV_HOUR_APPR_PROCESS_START_MEAN              24162    9.583038
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN  24162    9.583038
# PREV_NAME_TYPE_SUITE_Family_MEAN               24162    9.583038
# PREV_NAME_TYPE_SUITE_Children_MEAN             24162    9.583038
# PREV_CODE_REJECT_REASON_nan_MEAN               24162    9.583038
# ...                                              ...         ...
# INSTAL_DPD_MEAN                                13301    5.275390
# INSTAL_DPD_MAX                                 13301    5.275390
# INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE          13301    5.275390
# INSTAL_PAYMENT_PERC_SUM                        13301    5.275390
# INSTAL_COUNT                                   13301    5.275390
#
# [225 rows x 2 columns]

# %%
# en supprime les variables avec les DM<10% avant de les remplacée par les données imputées 

df_train_FE_ssDM= missing_final_inf10.drop(columns=missing_final_inf10_sup0.index.tolist())
df_train_FE_ssDM
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 252128      252128      456248       0            1             0
# 252129      252129      456251       0            0             0
# 252130      252130      456253       0            1             0
# 252131      252131      456254       1            1             0
# 252132      252132      456255       0            1             0
#
#         FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0       -9461           -637            -3648.0
# ...

# %%
missing_final_inf10.to_csv('C:/Users/kalin/missing_final_inf10.csv')

# %%
# Table avec variables ayant DM<10%

train_FE_DM_inf10 = df_train_FE[['SK_ID_CURR'
,'INSTAL_AMT_INSTALMENT_MAX'
,'INSTAL_AMT_INSTALMENT_MEAN'
,'INSTAL_AMT_INSTALMENT_SUM'
,'INSTAL_AMT_PAYMENT_MAX'
,'INSTAL_AMT_PAYMENT_MEAN'
,'INSTAL_AMT_PAYMENT_MIN'
,'INSTAL_AMT_PAYMENT_SUM'
,'INSTAL_COUNT'
,'INSTAL_DAYS_ENTRY_PAYMENT_MAX'
,'INSTAL_DAYS_ENTRY_PAYMENT_MEAN'
,'INSTAL_DAYS_ENTRY_PAYMENT_SUM'
,'INSTAL_DBD_MAX'
,'INSTAL_DBD_MEAN'
,'INSTAL_DBD_SUM'
,'INSTAL_DPD_MAX'
,'INSTAL_DPD_MEAN'
,'INSTAL_DPD_SUM'
,'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE'
,'INSTAL_PAYMENT_DIFF_MAX'
,'INSTAL_PAYMENT_DIFF_MEAN'
,'INSTAL_PAYMENT_DIFF_SUM'
,'INSTAL_PAYMENT_DIFF_VAR'
,'INSTAL_PAYMENT_PERC_MAX'
,'INSTAL_PAYMENT_PERC_MEAN'
,'INSTAL_PAYMENT_PERC_SUM'
,'INSTAL_PAYMENT_PERC_VAR'
,'POS_COUNT'
,'POS_MONTHS_BALANCE_MAX'
,'POS_MONTHS_BALANCE_MEAN'
,'POS_MONTHS_BALANCE_SIZE'
,'POS_NAME_CONTRACT_STATUS_Active_MEAN'
,'POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN'
,'POS_NAME_CONTRACT_STATUS_Approved_MEAN'
,'POS_NAME_CONTRACT_STATUS_Canceled_MEAN'
,'POS_NAME_CONTRACT_STATUS_Completed_MEAN'
,'POS_NAME_CONTRACT_STATUS_Demand_MEAN'
,'POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN'
,'POS_NAME_CONTRACT_STATUS_Signed_MEAN'
,'POS_NAME_CONTRACT_STATUS_XNA_MEAN'
,'POS_NAME_CONTRACT_STATUS_nan_MEAN'
,'POS_SK_DPD_DEF_MAX'
,'POS_SK_DPD_DEF_MEAN'
,'POS_SK_DPD_MAX'
,'POS_SK_DPD_MEAN'
,'PREV_AMT_ANNUITY_MAX'
,'PREV_AMT_ANNUITY_MEAN'
,'PREV_AMT_ANNUITY_MIN'
,'PREV_AMT_APPLICATION_MAX'
,'PREV_AMT_APPLICATION_MEAN'
,'PREV_AMT_APPLICATION_MIN'
,'PREV_AMT_CREDIT_MAX'
,'PREV_AMT_CREDIT_MEAN'
,'PREV_AMT_CREDIT_MIN'
,'PREV_AMT_GOODS_PRICE_MAX'
,'PREV_AMT_GOODS_PRICE_MEAN'
,'PREV_AMT_GOODS_PRICE_MIN'
,'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN'
,'PREV_CHANNEL_TYPE_Car dealer_MEAN'
,'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN'
,'PREV_CHANNEL_TYPE_Contact center_MEAN'
,'PREV_CHANNEL_TYPE_Country-wide_MEAN'
,'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN'
,'PREV_CHANNEL_TYPE_Regional / Local_MEAN'
,'PREV_CHANNEL_TYPE_Stone_MEAN'
,'PREV_CHANNEL_TYPE_nan_MEAN'
,'PREV_CNT_PAYMENT_MEAN'
,'PREV_CNT_PAYMENT_SUM'
,'PREV_CODE_REJECT_REASON_CLIENT_MEAN'
,'PREV_CODE_REJECT_REASON_HC_MEAN'
,'PREV_CODE_REJECT_REASON_LIMIT_MEAN'
,'PREV_CODE_REJECT_REASON_SCOFR_MEAN'
,'PREV_CODE_REJECT_REASON_SCO_MEAN'
,'PREV_CODE_REJECT_REASON_SYSTEM_MEAN'
,'PREV_CODE_REJECT_REASON_VERIF_MEAN'
,'PREV_CODE_REJECT_REASON_XAP_MEAN'
,'PREV_CODE_REJECT_REASON_XNA_MEAN'
,'PREV_CODE_REJECT_REASON_nan_MEAN'
,'PREV_DAYS_DECISION_MAX'
,'PREV_DAYS_DECISION_MEAN'
,'PREV_DAYS_DECISION_MIN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN'
,'PREV_HOUR_APPR_PROCESS_START_MAX'
,'PREV_HOUR_APPR_PROCESS_START_MEAN'
,'PREV_HOUR_APPR_PROCESS_START_MIN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN'
,'PREV_NAME_CLIENT_TYPE_New_MEAN'
,'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN'
,'PREV_NAME_CLIENT_TYPE_Repeater_MEAN'
,'PREV_NAME_CLIENT_TYPE_XNA_MEAN'
,'PREV_NAME_CLIENT_TYPE_nan_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Approved_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Refused_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN'
,'PREV_NAME_CONTRACT_STATUS_nan_MEAN'
,'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN'
,'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN'
,'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN'
,'PREV_NAME_CONTRACT_TYPE_XNA_MEAN'
,'PREV_NAME_CONTRACT_TYPE_nan_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Animals_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Computers_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Education_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Fitness_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Gardening_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Homewares_MEAN'
,'PREV_NAME_GOODS_CATEGORY_House Construction_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Insurance_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Medicine_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Other_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Tourism_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Weapon_MEAN'
,'PREV_NAME_GOODS_CATEGORY_XNA_MEAN'
,'PREV_NAME_GOODS_CATEGORY_nan_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN'
,'PREV_NAME_PAYMENT_TYPE_XNA_MEAN'
,'PREV_NAME_PAYMENT_TYPE_nan_MEAN'
,'PREV_NAME_PORTFOLIO_Cards_MEAN'
,'PREV_NAME_PORTFOLIO_Cars_MEAN'
,'PREV_NAME_PORTFOLIO_Cash_MEAN'
,'PREV_NAME_PORTFOLIO_POS_MEAN'
,'PREV_NAME_PORTFOLIO_XNA_MEAN'
,'PREV_NAME_PORTFOLIO_nan_MEAN'
,'PREV_NAME_PRODUCT_TYPE_XNA_MEAN'
,'PREV_NAME_PRODUCT_TYPE_nan_MEAN'
,'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN'
,'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_nan_MEAN'
,'PREV_NAME_TYPE_SUITE_Children_MEAN'
,'PREV_NAME_TYPE_SUITE_Family_MEAN'
,'PREV_NAME_TYPE_SUITE_Group of people_MEAN'
,'PREV_NAME_TYPE_SUITE_Missing_MEAN'
,'PREV_NAME_TYPE_SUITE_Other_A_MEAN'
,'PREV_NAME_TYPE_SUITE_Other_B_MEAN'
,'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN'
,'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN'
,'PREV_NAME_TYPE_SUITE_nan_MEAN'
,'PREV_NAME_YIELD_GROUP_XNA_MEAN'
,'PREV_NAME_YIELD_GROUP_high_MEAN'
,'PREV_NAME_YIELD_GROUP_low_action_MEAN'
,'PREV_NAME_YIELD_GROUP_low_normal_MEAN'
,'PREV_NAME_YIELD_GROUP_middle_MEAN'
,'PREV_NAME_YIELD_GROUP_nan_MEAN'
,'PREV_PRODUCT_COMBINATION_Card Street_MEAN'
,'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash_MEAN'
,'PREV_PRODUCT_COMBINATION_Missing_MEAN'
,'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_nan_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN'
]]

# %%
train_FE_DM_inf10
# Out:
#         SK_ID_CURR  INSTAL_AMT_INSTALMENT_MAX  INSTAL_AMT_INSTALMENT_MEAN  \
# 0           100002                  53093.745                11559.247105
# 1           100003                 560835.360                64754.586000
# 2           100004                  10573.965                 7096.155000
# 3           100006                 691786.890                62947.088438
# 4           100007                  22678.785                12666.444545
# ...            ...                        ...                         ...
# 252128      456248                  67725.495                44619.088696
# 252129      456251                  12815.010                 7492.924286
# 252130      456253                   5575.185                 4399.707857
# 252131      456254                  19065.825                10239.832895
# 252132      456255                 615229.515                41464.713649
#
#         INSTAL_AMT_INSTALMENT_SUM  INSTAL_AMT_PAYMENT_MAX  \
# ...

# %%
# Remplacer DM en utilisant la médiane

def DM_mediane (data, var):
    median = data[var].median()
    data[var].fillna(median, inplace=True)

# %%
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_INSTALMENT_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_INSTALMENT_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_INSTALMENT_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_PAYMENT_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_PAYMENT_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_PAYMENT_MIN')
DM_mediane(train_FE_DM_inf10,'INSTAL_AMT_PAYMENT_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_COUNT')
DM_mediane(train_FE_DM_inf10,'INSTAL_DAYS_ENTRY_PAYMENT_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_DAYS_ENTRY_PAYMENT_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_DAYS_ENTRY_PAYMENT_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_DBD_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_DBD_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_DBD_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_DPD_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_DPD_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_DPD_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_DIFF_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_DIFF_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_DIFF_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_DIFF_VAR')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_PERC_MAX')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_PERC_MEAN')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_PERC_SUM')
DM_mediane(train_FE_DM_inf10,'INSTAL_PAYMENT_PERC_VAR')
DM_mediane(train_FE_DM_inf10,'POS_COUNT')
DM_mediane(train_FE_DM_inf10,'POS_MONTHS_BALANCE_MAX')
DM_mediane(train_FE_DM_inf10,'POS_MONTHS_BALANCE_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_MONTHS_BALANCE_SIZE')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Active_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Approved_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Canceled_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Completed_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Demand_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_Signed_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_NAME_CONTRACT_STATUS_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_SK_DPD_DEF_MAX')
DM_mediane(train_FE_DM_inf10,'POS_SK_DPD_DEF_MEAN')
DM_mediane(train_FE_DM_inf10,'POS_SK_DPD_MAX')
DM_mediane(train_FE_DM_inf10,'POS_SK_DPD_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_ANNUITY_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_ANNUITY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_ANNUITY_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_APPLICATION_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_APPLICATION_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_APPLICATION_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_CREDIT_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_CREDIT_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_CREDIT_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_GOODS_PRICE_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_GOODS_PRICE_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_AMT_GOODS_PRICE_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Car dealer_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Contact center_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Country-wide_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Regional / Local_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_Stone_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CHANNEL_TYPE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CNT_PAYMENT_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CNT_PAYMENT_SUM')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_CLIENT_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_HC_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_LIMIT_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_SCOFR_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_SCO_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_SYSTEM_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_VERIF_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_XAP_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_CODE_REJECT_REASON_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_DAYS_DECISION_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_DAYS_DECISION_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_DAYS_DECISION_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_HOUR_APPR_PROCESS_START_MAX')
DM_mediane(train_FE_DM_inf10,'PREV_HOUR_APPR_PROCESS_START_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_HOUR_APPR_PROCESS_START_MIN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CLIENT_TYPE_New_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CLIENT_TYPE_Repeater_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CLIENT_TYPE_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CLIENT_TYPE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_STATUS_Approved_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_STATUS_Refused_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_STATUS_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_TYPE_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_CONTRACT_TYPE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Animals_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Computers_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Education_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Fitness_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Gardening_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Homewares_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_House Construction_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Insurance_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Medicine_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Other_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Tourism_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_Weapon_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_GOODS_CATEGORY_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PAYMENT_TYPE_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PAYMENT_TYPE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_Cards_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_Cars_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_Cash_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_POS_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PORTFOLIO_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PRODUCT_TYPE_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PRODUCT_TYPE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_SELLER_INDUSTRY_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Children_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Family_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Group of people_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Missing_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Other_A_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Other_B_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_TYPE_SUITE_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_XNA_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_high_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_low_action_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_low_normal_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_middle_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_NAME_YIELD_GROUP_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Card Street_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Cash_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_Missing_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_PRODUCT_COMBINATION_nan_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN')
DM_mediane(train_FE_DM_inf10,'PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN')
# Out:
# C:\Users\kalin\anaconda3\envs\OCR5\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# merger avec la table ayant des données imputées pour quand DM<10%

train_FE_ssDM = df_train_FE_ssDM.merge(train_FE_DM_inf10, how='inner', on='SK_ID_CURR')

# %%
train_FE_ssDM
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 252128      252128      456248       0            1             0
# 252129      252129      456251       0            0             0
# 252130      252130      456253       0            1             0
# 252131      252131      456254       1            1             0
# 252132      252132      456255       0            1             0
#
#         FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0       -9461           -637            -3648.0
# ...

# %%
count = train_FE_ssDM .isnull().sum().sort_values(ascending=False)
percentage = ((train_FE_ssDM .isnull().sum()/len(train_FE_ssDM )*100)).sort_values(ascending=False)
missing = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing
# Out:
# Count and percentage of missing values s:
#                                                     Count  Percentage
# Unnamed: 0                                              0         0.0
# PREV_CODE_REJECT_REASON_CLIENT_MEAN                     0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN       0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN          0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday ho...      0         0.0
# ...                                                   ...         ...
# ORGANIZATION_TYPE_Business Entity Type 3                0         0.0
# ORGANIZATION_TYPE_Business Entity Type 2                0         0.0
# ORGANIZATION_TYPE_Business Entity Type 1                0         0.0
# ORGANIZATION_TYPE_Bank                                  0         0.0
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN                0         0.0
#
# [422 rows x 2 columns]

# %% [markdown]
# # fichier CSV table finale train sans données manquantes

# %%
train_FE_ssDM.to_csv('C:/Users/kalin/train_FE_ssDM.csv')

# %%
train_FE_ssDM
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 252128      252128      456248       0            1             0
# 252129      252129      456251       0            0             0
# 252130      252130      456253       0            1             0
# 252131      252131      456254       1            1             0
# 252132      252132      456255       0            1             0
#
#         FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                     0       -9461           -637            -3648.0
# ...

# %% [markdown]
# # DOnnées manquantes pour la table TEST

# %%
df_test_FE= pd.DataFrame(pd.read_csv('C:/Users/kalin/df_test_FE.csv'))

# %%
df_test_FE
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  SK_ID_CURR  CODE_GENDER  \
# 0               0             0               0      100001            0
# 1               1             1               1      100005            1
# 2               2             2               2      100013            1
# 3               3             3               3      100028            0
# 4               4             4               4      100038            1
# ...           ...           ...             ...         ...          ...
# 39465       39465         39465           48739      456221            0
# 39466       39466         39466           48740      456222            0
# 39467       39467         39467           48741      456223            0
# 39468       39468         39468           48742      456224            1
# 39469       39469         39469           48743      456250            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
# pourcentage de données manquantes de chaque variables :
count = df_test_FE.isnull().sum().sort_values(ascending=False)
percentage = ((df_test_FE.isnull().sum()/len(df_test_FE)*100)).sort_values(ascending=False)
missing_df_test_FE = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing_df_test_FE
# Out:
# Count and percentage of missing values s:
#                                      Count  Percentage
# CC_MONTHS_BALANCE_VAR                39470  100.000000
# REFUSED_APP_CREDIT_PERC_VAR          32295   81.821637
# CC_MONTHS_BALANCE_MAX                31335   79.389410
# CC_MONTHS_BALANCE_MEAN               31335   79.389410
# CC_MONTHS_BALANCE_MIN                31335   79.389410
# ...                                    ...         ...
# WEEKDAY_APPR_PROCESS_START_TUESDAY       0    0.000000
# WEEKDAY_APPR_PROCESS_START_THURSDAY      0    0.000000
# WEEKDAY_APPR_PROCESS_START_SUNDAY        0    0.000000
# WEEKDAY_APPR_PROCESS_START_SATURDAY      0    0.000000
# Unnamed: 0                               0    0.000000
#
# [725 rows x 2 columns]

# %%
#DM par ligne 
DM_ligne = pd.DataFrame(df_test_FE.isnull().sum(axis=1))
DM_ligne
# Out:
#          0
# 0      172
# 1      173
# 2       49
# 3       25
# 4      278
# ...    ...
# 39465  172
# 39466  277
# 39467  173
# 39468  147
# 39469    3
#
# [39470 rows x 1 columns]

# %%
DM_ligne_inf90 = DM_ligne[DM_ligne[0]<581]
DM_ligne_inf90
# Out:
#          0
# 0      172
# 1      173
# 2       49
# 3       25
# 4      278
# ...    ...
# 39465  172
# 39466  277
# 39467  173
# 39468  147
# 39469    3
#
# [39470 rows x 1 columns]

# %%
# On garde les variables avec moins de 10% de DM
# variables ayant moins de 10% de DM
missing_final_sup10=missing_df_test_FE[ missing_df_test_FE['Percentage'] >10]
missing_final_sup10
# Out:
#                                             Count  Percentage
# CC_MONTHS_BALANCE_VAR                       39470  100.000000
# REFUSED_APP_CREDIT_PERC_VAR                 32295   81.821637
# CC_MONTHS_BALANCE_MAX                       31335   79.389410
# CC_MONTHS_BALANCE_MEAN                      31335   79.389410
# CC_MONTHS_BALANCE_MIN                       31335   79.389410
# ...                                           ...         ...
# BURO_CREDIT_ACTIVE_Bad debt_MEAN             5367   13.597669
# BURO_CREDIT_TYPE_Mortgage_MEAN               5367   13.597669
# BURO_CREDIT_TYPE_Real estate loan_MEAN       5367   13.597669
# BURO_CREDIT_TYPE_Unknown type of loan_MEAN   5367   13.597669
# BURO_CREDIT_TYPE_Mobile operator loan_MEAN   5367   13.597669
#
# [279 rows x 2 columns]

# %%
# supression des variables qui ont plus de 10% de données manquantes 

missing_final_inf10 = df_test_FE.drop(columns=missing_final_sup10.index.tolist())
missing_final_inf10
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  SK_ID_CURR  CODE_GENDER  \
# 0               0             0               0      100001            0
# 1               1             1               1      100005            1
# 2               2             2               2      100013            1
# 3               3             3               3      100028            0
# 4               4             4               4      100038            1
# ...           ...           ...             ...         ...          ...
# 39465       39465         39465           48739      456221            0
# 39466       39466         39466           48740      456222            0
# 39467       39467         39467           48741      456223            0
# 39468       39468         39468           48742      456224            1
# 39469       39469         39469           48743      456250            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
count = missing_final_inf10.isnull().sum().sort_values(ascending=False)
percentage = ((missing_final_inf10.isnull().sum()/len(missing_final_inf10)*100)).sort_values(ascending=False)
missing_final_inf10_2 = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing_final_inf10_2
# Out:
# Count and percentage of missing values s:
#                                      Count  Percentage
# APPROVED_APP_CREDIT_PERC_MAX          3094    7.838865
# APPROVED_APP_CREDIT_PERC_MEAN         3094    7.838865
# APPROVED_APP_CREDIT_PERC_MIN          3094    7.838865
# APPROVED_AMT_CREDIT_MEAN              3093    7.836331
# APPROVED_AMT_GOODS_PRICE_MIN          3093    7.836331
# ...                                    ...         ...
# WEEKDAY_APPR_PROCESS_START_TUESDAY       0    0.000000
# WEEKDAY_APPR_PROCESS_START_THURSDAY      0    0.000000
# WEEKDAY_APPR_PROCESS_START_SUNDAY        0    0.000000
# WEEKDAY_APPR_PROCESS_START_SATURDAY      0    0.000000
# Unnamed: 0                               0    0.000000
#
# [446 rows x 2 columns]

# %%
missing_final_inf10_sup0 =missing_final_inf10_2[ missing_final_inf10_2['Percentage'] >1]
missing_final_inf10_sup0
# Out:
#                                Count  Percentage
# APPROVED_APP_CREDIT_PERC_MAX    3094    7.838865
# APPROVED_APP_CREDIT_PERC_MEAN   3094    7.838865
# APPROVED_APP_CREDIT_PERC_MIN    3094    7.838865
# APPROVED_AMT_CREDIT_MEAN        3093    7.836331
# APPROVED_AMT_GOODS_PRICE_MIN    3093    7.836331
# ...                              ...         ...
# INSTAL_DPD_SUM                   680    1.722827
# INSTAL_DPD_MEAN                  680    1.722827
# INSTAL_DPD_MAX                   680    1.722827
# INSTAL_PAYMENT_PERC_SUM          680    1.722827
# INSTAL_COUNT                     680    1.722827
#
# [251 rows x 2 columns]

# %%
missing_final_inf10_sup0.to_csv('C:/Users/kalin/missing_final_inf10_sup0.csv')

# %%
#suppression des variables qui ont moin de 10% de DM avant leur imputation 

df_test_FE_ssDM= missing_final_inf10.drop(columns=missing_final_inf10_sup0.index.tolist())
df_test_FE_ssDM
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  SK_ID_CURR  CODE_GENDER  \
# 0               0             0               0      100001            0
# 1               1             1               1      100005            1
# 2               2             2               2      100013            1
# 3               3             3               3      100028            0
# 4               4             4               4      100038            1
# ...           ...           ...             ...         ...          ...
# 39465       39465         39465           48739      456221            0
# 39466       39466         39466           48740      456222            0
# 39467       39467         39467           48741      456223            0
# 39468       39468         39468           48742      456224            1
# 39469       39469         39469           48743      456250            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
# a imputer 
a_imputer  = df_test_FE[['SK_ID_CURR'
 ,'APPROVED_APP_CREDIT_PERC_MAX'
,'APPROVED_APP_CREDIT_PERC_MIN'
,'APPROVED_APP_CREDIT_PERC_MEAN'
,'APPROVED_AMT_GOODS_PRICE_MAX'
,'APPROVED_AMT_CREDIT_MEAN'
,'APPROVED_AMT_CREDIT_MAX'
,'APPROVED_AMT_GOODS_PRICE_MIN'
,'APPROVED_AMT_APPLICATION_MEAN'
,'APPROVED_AMT_APPLICATION_MAX'
,'APPROVED_AMT_APPLICATION_MIN'
,'APPROVED_AMT_ANNUITY_MEAN'
,'APPROVED_AMT_ANNUITY_MAX'
,'APPROVED_AMT_ANNUITY_MIN'
,'APPROVED_AMT_CREDIT_MIN'
,'APPROVED_HOUR_APPR_PROCESS_START_MIN'
,'APPROVED_HOUR_APPR_PROCESS_START_MAX'
,'APPROVED_HOUR_APPR_PROCESS_START_MEAN'
,'APPROVED_DAYS_DECISION_MIN'
,'APPROVED_DAYS_DECISION_MAX'
,'APPROVED_DAYS_DECISION_MEAN'
,'APPROVED_CNT_PAYMENT_MEAN'
,'APPROVED_CNT_PAYMENT_SUM'
,'APPROVED_AMT_GOODS_PRICE_MEAN'
,'PREV_APP_CREDIT_PERC_MIN'
,'PREV_APP_CREDIT_PERC_MAX'
,'PREV_APP_CREDIT_PERC_MEAN'
,'PREV_NAME_PAYMENT_TYPE_XNA_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN'
,'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN'
,'PREV_NAME_CONTRACT_STATUS_nan_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Refused_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN'
,'PREV_NAME_CONTRACT_STATUS_Approved_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN'
,'PREV_NAME_CONTRACT_TYPE_nan_MEAN'
,'PREV_NAME_PAYMENT_TYPE_nan_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN'
,'PREV_CODE_REJECT_REASON_CLIENT_MEAN'
,'PREV_NAME_CLIENT_TYPE_Repeater_MEAN'
,'PREV_NAME_CLIENT_TYPE_XNA_MEAN'
,'PREV_NAME_CLIENT_TYPE_nan_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Animals_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Computers_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Education_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Fitness_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Gardening_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Homewares_MEAN'
,'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN'
,'PREV_NAME_CLIENT_TYPE_New_MEAN'
,'PREV_NAME_TYPE_SUITE_nan_MEAN'
,'PREV_CODE_REJECT_REASON_XNA_MEAN'
,'PREV_CODE_REJECT_REASON_HC_MEAN'
,'PREV_CODE_REJECT_REASON_LIMIT_MEAN'
,'PREV_CODE_REJECT_REASON_SCO_MEAN'
,'PREV_CODE_REJECT_REASON_SCOFR_MEAN'
,'PREV_CODE_REJECT_REASON_SYSTEM_MEAN'
,'PREV_CODE_REJECT_REASON_VERIF_MEAN'
,'PREV_CODE_REJECT_REASON_XAP_MEAN'
,'PREV_CODE_REJECT_REASON_nan_MEAN'
,'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN'
,'PREV_NAME_TYPE_SUITE_Children_MEAN'
,'PREV_NAME_TYPE_SUITE_Family_MEAN'
,'PREV_NAME_TYPE_SUITE_Group of people_MEAN'
,'PREV_NAME_TYPE_SUITE_Missing_MEAN'
,'PREV_NAME_TYPE_SUITE_Other_A_MEAN'
,'PREV_NAME_TYPE_SUITE_Other_B_MEAN'
,'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN'
,'PREV_AMT_CREDIT_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN'
,'PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN'
,'PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN'
,'PREV_NAME_CONTRACT_TYPE_XNA_MEAN'
,'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN'
,'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN'
,'PREV_AMT_ANNUITY_MIN'
,'PREV_AMT_ANNUITY_MAX'
,'PREV_AMT_ANNUITY_MEAN'
,'PREV_AMT_APPLICATION_MIN'
,'PREV_AMT_APPLICATION_MAX'
,'PREV_AMT_APPLICATION_MEAN'
,'PREV_AMT_CREDIT_MIN'
,'PREV_AMT_CREDIT_MAX'
,'PREV_NAME_GOODS_CATEGORY_Insurance_MEAN'
,'PREV_AMT_GOODS_PRICE_MIN'
,'PREV_AMT_GOODS_PRICE_MAX'
,'PREV_AMT_GOODS_PRICE_MEAN'
,'PREV_HOUR_APPR_PROCESS_START_MIN'
,'PREV_HOUR_APPR_PROCESS_START_MAX'
,'PREV_HOUR_APPR_PROCESS_START_MEAN'
,'PREV_DAYS_DECISION_MIN'
,'PREV_DAYS_DECISION_MAX'
,'PREV_DAYS_DECISION_MEAN'
,'PREV_CNT_PAYMENT_MEAN'
,'PREV_CNT_PAYMENT_SUM'
,'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN'
,'PREV_NAME_GOODS_CATEGORY_House Construction_MEAN'
,'PREV_NAME_GOODS_CATEGORY_XNA_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN'
,'PREV_NAME_YIELD_GROUP_XNA_MEAN'
,'PREV_PRODUCT_COMBINATION_Card Street_MEAN'
,'PREV_NAME_YIELD_GROUP_nan_MEAN'
,'PREV_NAME_YIELD_GROUP_middle_MEAN'
,'PREV_NAME_YIELD_GROUP_low_normal_MEAN'
,'PREV_NAME_YIELD_GROUP_low_action_MEAN'
,'PREV_NAME_YIELD_GROUP_high_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_nan_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN'
,'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN'
,'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_nan_MEAN'
,'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN'
,'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN'
,'PREV_PRODUCT_COMBINATION_Missing_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN'
,'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Tourism_MEAN'
,'PREV_NAME_PORTFOLIO_Cars_MEAN'
,'PREV_NAME_PORTFOLIO_Cards_MEAN'
,'PREV_NAME_GOODS_CATEGORY_nan_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Weapon_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN'
,'PREV_NAME_PORTFOLIO_POS_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Other_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN'
,'PREV_NAME_GOODS_CATEGORY_Medicine_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN'
,'PREV_NAME_PORTFOLIO_Cash_MEAN'
,'PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN'
,'PREV_NAME_PORTFOLIO_XNA_MEAN'
,'PREV_CHANNEL_TYPE_Contact center_MEAN'
,'PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN'
,'PREV_NAME_PORTFOLIO_nan_MEAN'
,'PREV_CHANNEL_TYPE_nan_MEAN'
,'PREV_CHANNEL_TYPE_Stone_MEAN'
,'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN'
,'PREV_CHANNEL_TYPE_Country-wide_MEAN'
,'PREV_CHANNEL_TYPE_Regional / Local_MEAN'
,'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN'
,'PREV_CHANNEL_TYPE_Car dealer_MEAN'
,'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN'
,'PREV_NAME_PRODUCT_TYPE_nan_MEAN'
,'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN'
,'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN'
,'PREV_NAME_PRODUCT_TYPE_XNA_MEAN'
,'POS_NAME_CONTRACT_STATUS_Approved_MEAN'
,'POS_COUNT'
,'POS_NAME_CONTRACT_STATUS_nan_MEAN'
,'POS_NAME_CONTRACT_STATUS_XNA_MEAN'
,'POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN'
,'POS_NAME_CONTRACT_STATUS_Demand_MEAN'
,'POS_NAME_CONTRACT_STATUS_Completed_MEAN'
,'POS_NAME_CONTRACT_STATUS_Canceled_MEAN'
,'POS_NAME_CONTRACT_STATUS_Signed_MEAN'
,'POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN'
,'POS_MONTHS_BALANCE_SIZE'
,'POS_NAME_CONTRACT_STATUS_Active_MEAN'
,'POS_MONTHS_BALANCE_MAX'
,'POS_MONTHS_BALANCE_MEAN'
,'POS_SK_DPD_DEF_MAX'
,'POS_SK_DPD_MAX'
,'POS_SK_DPD_DEF_MEAN'
,'POS_SK_DPD_MEAN'
,'INSTAL_PAYMENT_PERC_VAR'
,'INSTAL_PAYMENT_DIFF_VAR'
,'INSTAL_DAYS_ENTRY_PAYMENT_SUM'
,'INSTAL_DAYS_ENTRY_PAYMENT_MEAN'
,'INSTAL_DAYS_ENTRY_PAYMENT_MAX'
,'INSTAL_AMT_PAYMENT_SUM'
,'INSTAL_AMT_PAYMENT_MEAN'
,'INSTAL_AMT_PAYMENT_MAX'
,'INSTAL_AMT_PAYMENT_MIN'
,'INSTAL_AMT_INSTALMENT_SUM'
,'INSTAL_AMT_INSTALMENT_MEAN'
,'INSTAL_AMT_INSTALMENT_MAX'
,'INSTAL_PAYMENT_DIFF_MEAN'
,'INSTAL_PAYMENT_DIFF_SUM'
,'INSTAL_PAYMENT_DIFF_MAX'
,'INSTAL_PAYMENT_PERC_MEAN'
,'INSTAL_PAYMENT_PERC_MAX'
,'INSTAL_DBD_SUM'
,'INSTAL_DBD_MEAN'
,'INSTAL_DBD_MAX'
,'INSTAL_DPD_SUM'
,'INSTAL_DPD_MEAN'
,'INSTAL_DPD_MAX'
,'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE'
,'INSTAL_PAYMENT_PERC_SUM'
,'INSTAL_COUNT']]

# %%
a_imputer
# Out:
#        SK_ID_CURR  APPROVED_APP_CREDIT_PERC_MAX  APPROVED_APP_CREDIT_PERC_MIN  \
# 0          100001                      1.004280                      1.004280
# 1          100005                      1.009944                      1.009944
# 2          100013                      1.005807                      0.990127
# 3          100028                      1.009337                      1.000000
# 4          100038                      0.988243                      0.988243
# ...           ...                           ...                           ...
# 39465      456221                      0.990040                      0.990040
# 39466      456222                      1.005541                      0.983626
# 39467      456223                      1.008824                      1.008824
# 39468      456224                      1.003245                      1.003245
# 39469      456250                      0.996470                      0.994841
#
# ...

# %%
count = a_imputer.isnull().sum().sort_values(ascending=False)
count
# Out:
# APPROVED_APP_CREDIT_PERC_MIN      3094
# APPROVED_APP_CREDIT_PERC_MEAN     3094
# APPROVED_APP_CREDIT_PERC_MAX      3094
# APPROVED_DAYS_DECISION_MIN        3093
# APPROVED_AMT_CREDIT_MIN           3093
#                                   ...
# INSTAL_AMT_PAYMENT_SUM             680
# INSTAL_DAYS_ENTRY_PAYMENT_MAX      680
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN     680
# INSTAL_DAYS_ENTRY_PAYMENT_SUM      680
# SK_ID_CURR                           0
# Length: 252, dtype: int64

# %%
count = a_imputer.isnull().sum().sort_values(ascending=False)
percentage = ((a_imputer.isnull().sum()/len(a_imputer)*100)).sort_values(ascending=False)
missing = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing
# Out:
# Count and percentage of missing values s:
#                                 Count  Percentage
# APPROVED_APP_CREDIT_PERC_MIN     3094    7.838865
# APPROVED_APP_CREDIT_PERC_MEAN    3094    7.838865
# APPROVED_APP_CREDIT_PERC_MAX     3094    7.838865
# APPROVED_DAYS_DECISION_MIN       3093    7.836331
# APPROVED_AMT_CREDIT_MIN          3093    7.836331
# ...                               ...         ...
# INSTAL_AMT_PAYMENT_SUM            680    1.722827
# INSTAL_DAYS_ENTRY_PAYMENT_MAX     680    1.722827
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN    680    1.722827
# INSTAL_DAYS_ENTRY_PAYMENT_SUM     680    1.722827
# SK_ID_CURR                          0    0.000000
#
# [252 rows x 2 columns]

# %%
#imputation des variables qui ont moins de 10% de DM

DM_mediane(a_imputer,'APPROVED_APP_CREDIT_PERC_MAX')
DM_mediane(a_imputer,'APPROVED_APP_CREDIT_PERC_MIN')
DM_mediane(a_imputer,'APPROVED_APP_CREDIT_PERC_MEAN')
DM_mediane(a_imputer,'APPROVED_AMT_GOODS_PRICE_MAX')
DM_mediane(a_imputer,'APPROVED_AMT_CREDIT_MEAN')
DM_mediane(a_imputer,'APPROVED_AMT_CREDIT_MAX')
DM_mediane(a_imputer,'APPROVED_AMT_GOODS_PRICE_MIN')
DM_mediane(a_imputer,'APPROVED_AMT_APPLICATION_MEAN')
DM_mediane(a_imputer,'APPROVED_AMT_APPLICATION_MAX')
DM_mediane(a_imputer,'APPROVED_AMT_APPLICATION_MIN')
DM_mediane(a_imputer,'APPROVED_AMT_ANNUITY_MEAN')
DM_mediane(a_imputer,'APPROVED_AMT_ANNUITY_MAX')
DM_mediane(a_imputer,'APPROVED_AMT_ANNUITY_MIN')
DM_mediane(a_imputer,'APPROVED_AMT_CREDIT_MIN')
DM_mediane(a_imputer,'APPROVED_HOUR_APPR_PROCESS_START_MIN')
DM_mediane(a_imputer,'APPROVED_HOUR_APPR_PROCESS_START_MAX')
DM_mediane(a_imputer,'APPROVED_HOUR_APPR_PROCESS_START_MEAN')
DM_mediane(a_imputer,'APPROVED_DAYS_DECISION_MIN')
DM_mediane(a_imputer,'APPROVED_DAYS_DECISION_MAX')
DM_mediane(a_imputer,'APPROVED_DAYS_DECISION_MEAN')
DM_mediane(a_imputer,'APPROVED_CNT_PAYMENT_MEAN')
DM_mediane(a_imputer,'APPROVED_CNT_PAYMENT_SUM')
DM_mediane(a_imputer,'APPROVED_AMT_GOODS_PRICE_MEAN')
DM_mediane(a_imputer,'PREV_APP_CREDIT_PERC_MIN')
DM_mediane(a_imputer,'PREV_APP_CREDIT_PERC_MAX')
DM_mediane(a_imputer,'PREV_APP_CREDIT_PERC_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PAYMENT_TYPE_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_STATUS_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_STATUS_Refused_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_STATUS_Approved_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_TYPE_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PAYMENT_TYPE_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_CLIENT_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CLIENT_TYPE_Repeater_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CLIENT_TYPE_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CLIENT_TYPE_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Animals_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Computers_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Education_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Fitness_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Gardening_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Homewares_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CLIENT_TYPE_New_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_nan_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_XNA_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_HC_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_LIMIT_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_SCO_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_SCOFR_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_SYSTEM_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_VERIF_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_XAP_MEAN')
DM_mediane(a_imputer,'PREV_CODE_REJECT_REASON_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Children_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Family_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Group of people_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Missing_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Other_A_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Other_B_MEAN')
DM_mediane(a_imputer,'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN')
DM_mediane(a_imputer,'PREV_AMT_CREDIT_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN')
DM_mediane(a_imputer,'PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN')
DM_mediane(a_imputer,'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN')
DM_mediane(a_imputer,'PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN')
DM_mediane(a_imputer,'PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_TYPE_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN')
DM_mediane(a_imputer,'PREV_AMT_ANNUITY_MIN')
DM_mediane(a_imputer,'PREV_AMT_ANNUITY_MAX')
DM_mediane(a_imputer,'PREV_AMT_ANNUITY_MEAN')
DM_mediane(a_imputer,'PREV_AMT_APPLICATION_MIN')
DM_mediane(a_imputer,'PREV_AMT_APPLICATION_MAX')
DM_mediane(a_imputer,'PREV_AMT_APPLICATION_MEAN')
DM_mediane(a_imputer,'PREV_AMT_CREDIT_MIN')
DM_mediane(a_imputer,'PREV_AMT_CREDIT_MAX')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Insurance_MEAN')
DM_mediane(a_imputer,'PREV_AMT_GOODS_PRICE_MIN')
DM_mediane(a_imputer,'PREV_AMT_GOODS_PRICE_MAX')
DM_mediane(a_imputer,'PREV_AMT_GOODS_PRICE_MEAN')
DM_mediane(a_imputer,'PREV_HOUR_APPR_PROCESS_START_MIN')
DM_mediane(a_imputer,'PREV_HOUR_APPR_PROCESS_START_MAX')
DM_mediane(a_imputer,'PREV_HOUR_APPR_PROCESS_START_MEAN')
DM_mediane(a_imputer,'PREV_DAYS_DECISION_MIN')
DM_mediane(a_imputer,'PREV_DAYS_DECISION_MAX')
DM_mediane(a_imputer,'PREV_DAYS_DECISION_MEAN')
DM_mediane(a_imputer,'PREV_CNT_PAYMENT_MEAN')
DM_mediane(a_imputer,'PREV_CNT_PAYMENT_SUM')
DM_mediane(a_imputer,'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_House Construction_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_XNA_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Card Street_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_middle_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_low_normal_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_low_action_MEAN')
DM_mediane(a_imputer,'PREV_NAME_YIELD_GROUP_high_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_nan_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_nan_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Missing_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN')
DM_mediane(a_imputer,'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Tourism_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_Cars_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_Cards_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Weapon_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_POS_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Other_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN')
DM_mediane(a_imputer,'PREV_NAME_GOODS_CATEGORY_Medicine_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_Cash_MEAN')
DM_mediane(a_imputer,'PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_XNA_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Contact center_MEAN')
DM_mediane(a_imputer,'PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PORTFOLIO_nan_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_nan_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Stone_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Country-wide_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Regional / Local_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_Car dealer_MEAN')
DM_mediane(a_imputer,'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PRODUCT_TYPE_nan_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN')
DM_mediane(a_imputer,'PREV_NAME_PRODUCT_TYPE_XNA_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Approved_MEAN')
DM_mediane(a_imputer,'POS_COUNT')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_nan_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_XNA_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Demand_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Completed_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Canceled_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Signed_MEAN')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN')
DM_mediane(a_imputer,'POS_MONTHS_BALANCE_SIZE')
DM_mediane(a_imputer,'POS_NAME_CONTRACT_STATUS_Active_MEAN')
DM_mediane(a_imputer,'POS_MONTHS_BALANCE_MAX')
DM_mediane(a_imputer,'POS_MONTHS_BALANCE_MEAN')
DM_mediane(a_imputer,'POS_SK_DPD_DEF_MAX')
DM_mediane(a_imputer,'POS_SK_DPD_MAX')
DM_mediane(a_imputer,'POS_SK_DPD_DEF_MEAN')
DM_mediane(a_imputer,'POS_SK_DPD_MEAN')
DM_mediane(a_imputer,'INSTAL_PAYMENT_PERC_VAR')
DM_mediane(a_imputer,'INSTAL_PAYMENT_DIFF_VAR')
DM_mediane(a_imputer,'INSTAL_DAYS_ENTRY_PAYMENT_SUM')
DM_mediane(a_imputer,'INSTAL_DAYS_ENTRY_PAYMENT_MEAN')
DM_mediane(a_imputer,'INSTAL_DAYS_ENTRY_PAYMENT_MAX')
DM_mediane(a_imputer,'INSTAL_AMT_PAYMENT_SUM')
DM_mediane(a_imputer,'INSTAL_AMT_PAYMENT_MEAN')
DM_mediane(a_imputer,'INSTAL_AMT_PAYMENT_MAX')
DM_mediane(a_imputer,'INSTAL_AMT_PAYMENT_MIN')
DM_mediane(a_imputer,'INSTAL_AMT_INSTALMENT_SUM')
DM_mediane(a_imputer,'INSTAL_AMT_INSTALMENT_MEAN')
DM_mediane(a_imputer,'INSTAL_AMT_INSTALMENT_MAX')
DM_mediane(a_imputer,'INSTAL_PAYMENT_DIFF_MEAN')
DM_mediane(a_imputer,'INSTAL_PAYMENT_DIFF_SUM')
DM_mediane(a_imputer,'INSTAL_PAYMENT_DIFF_MAX')
DM_mediane(a_imputer,'INSTAL_PAYMENT_PERC_MEAN')
DM_mediane(a_imputer,'INSTAL_PAYMENT_PERC_MAX')
DM_mediane(a_imputer,'INSTAL_DBD_SUM')
DM_mediane(a_imputer,'INSTAL_DBD_MEAN')
DM_mediane(a_imputer,'INSTAL_DBD_MAX')
DM_mediane(a_imputer,'INSTAL_DPD_SUM')
DM_mediane(a_imputer,'INSTAL_DPD_MEAN')
DM_mediane(a_imputer,'INSTAL_DPD_MAX')
DM_mediane(a_imputer,'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE')
DM_mediane(a_imputer,'INSTAL_PAYMENT_PERC_SUM')
DM_mediane(a_imputer,'INSTAL_COUNT')
# Out:
# C:\Users\kalin\anaconda3\envs\OCR5\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
count = a_imputer.isnull().sum().sort_values(ascending=False)
percentage = ((a_imputer.isnull().sum()/len(a_imputer)*100)).sort_values(ascending=False)
missing = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing
# Out:
# Count and percentage of missing values s:
#                                                     Count  Percentage
# SK_ID_CURR                                              0         0.0
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN         0         0.0
# PREV_PRODUCT_COMBINATION_POS other with interes...      0         0.0
# PREV_PRODUCT_COMBINATION_POS mobile without int...      0         0.0
# PREV_PRODUCT_COMBINATION_POS mobile with intere...      0         0.0
# ...                                                   ...         ...
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN             0         0.0
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN           0         0.0
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN            0         0.0
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN          0         0.0
# INSTAL_COUNT                                            0         0.0
#
# [252 rows x 2 columns]

# %%
df_test_FE_ssDM
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  SK_ID_CURR  CODE_GENDER  \
# 0               0             0               0      100001            0
# 1               1             1               1      100005            1
# 2               2             2               2      100013            1
# 3               3             3               3      100028            0
# 4               4             4               4      100038            1
# ...           ...           ...             ...         ...          ...
# 39465       39465         39465           48739      456221            0
# 39466       39466         39466           48740      456222            0
# 39467       39467         39467           48741      456223            0
# 39468       39468         39468           48742      456224            1
# 39469       39469         39469           48743      456250            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
count = df_test_FE_ssDM.isnull().sum().sort_values(ascending=False)
count
# Out:
# Unnamed: 0                             0
# ORGANIZATION_TYPE_Industry: type 11    0
# WEEKDAY_APPR_PROCESS_START_MONDAY      0
# WEEKDAY_APPR_PROCESS_START_SATURDAY    0
# WEEKDAY_APPR_PROCESS_START_SUNDAY      0
#                                       ..
# AMT_REQ_CREDIT_BUREAU_HOUR             0
# AMT_REQ_CREDIT_BUREAU_DAY              0
# AMT_REQ_CREDIT_BUREAU_WEEK             0
# AMT_REQ_CREDIT_BUREAU_MON              0
# PAYMENT_RATE                           0
# Length: 195, dtype: int64

# %%
a_imputer
# Out:
#        SK_ID_CURR  APPROVED_APP_CREDIT_PERC_MAX  APPROVED_APP_CREDIT_PERC_MIN  \
# 0          100001                      1.004280                      1.004280
# 1          100005                      1.009944                      1.009944
# 2          100013                      1.005807                      0.990127
# 3          100028                      1.009337                      1.000000
# 4          100038                      0.988243                      0.988243
# ...           ...                           ...                           ...
# 39465      456221                      0.990040                      0.990040
# 39466      456222                      1.005541                      0.983626
# 39467      456223                      1.008824                      1.008824
# 39468      456224                      1.003245                      1.003245
# 39469      456250                      0.996470                      0.994841
#
# ...

# %%
count = a_imputer.isnull().sum().sort_values(ascending=False)
count
# Out:
# SK_ID_CURR                                                   0
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN              0
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN        0
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN    0
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN       0
#                                                             ..
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                  0
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                0
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                 0
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN               0
# INSTAL_COUNT                                                 0
# Length: 252, dtype: int64

# %%
test_FE_ssDM = df_test_FE_ssDM.merge(a_imputer, how='left', on='SK_ID_CURR')
test_FE_ssDM
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  SK_ID_CURR  CODE_GENDER  \
# 0               0             0               0      100001            0
# 1               1             1               1      100005            1
# 2               2             2               2      100013            1
# 3               3             3               3      100028            0
# 4               4             4               4      100038            1
# ...           ...           ...             ...         ...          ...
# 39465       39465         39465           48739      456221            0
# 39466       39466         39466           48740      456222            0
# 39467       39467         39467           48741      456223            0
# 39468       39468         39468           48742      456224            1
# 39469       39469         39469           48743      456250            0
#
#        FLAG_OWN_CAR  FLAG_OWN_REALTY  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
count = test_FE_ssDM.isnull().sum().sort_values(ascending=False)
percentage = ((test_FE_ssDM.isnull().sum()/len(test_FE_ssDM)*100)).sort_values(ascending=False)
missing = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing
# Out:
# Count and percentage of missing values s:
#                                                     Count  Percentage
# Unnamed: 0                                              0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday ho...      0         0.0
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN                        0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third p...      0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                  0         0.0
# ...                                                   ...         ...
# ORGANIZATION_TYPE_Industry: type 10                     0         0.0
# ORGANIZATION_TYPE_Industry: type 1                      0         0.0
# ORGANIZATION_TYPE_Housing                               0         0.0
# ORGANIZATION_TYPE_Hotel                                 0         0.0
# INSTAL_COUNT                                            0         0.0
#
# [446 rows x 2 columns]

# %%
a_imputer.columns
# Out:
# Index(['SK_ID_CURR', 'APPROVED_APP_CREDIT_PERC_MAX',
#        'APPROVED_APP_CREDIT_PERC_MIN', 'APPROVED_APP_CREDIT_PERC_MEAN',
#        'APPROVED_AMT_GOODS_PRICE_MAX', 'APPROVED_AMT_CREDIT_MEAN',
#        'APPROVED_AMT_CREDIT_MAX', 'APPROVED_AMT_GOODS_PRICE_MIN',
#        'APPROVED_AMT_APPLICATION_MEAN', 'APPROVED_AMT_APPLICATION_MAX',
#        ...
#        'INSTAL_PAYMENT_PERC_MAX', 'INSTAL_DBD_SUM', 'INSTAL_DBD_MEAN',
#        'INSTAL_DBD_MAX', 'INSTAL_DPD_SUM', 'INSTAL_DPD_MEAN', 'INSTAL_DPD_MAX',
#        'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE', 'INSTAL_PAYMENT_PERC_SUM',
#        'INSTAL_COUNT'],
#       dtype='object', length=252)

# %%
test_FE_ssDM.to_csv('C:/Users/kalin/test_FE_ssDM.csv')

# %%
count = test_FE_ssDM.isnull().sum().sort_values(ascending=False)
percentage = ((test_FE_ssDM.isnull().sum()/len(test_FE_ssDM)*100)).sort_values(ascending=False)
missing = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])
print('Count and percentage of missing values s:')
missing
# Out:
# Count and percentage of missing values s:
#                                                     Count  Percentage
# Unnamed: 0                                              0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday ho...      0         0.0
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN                        0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third p...      0         0.0
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                  0         0.0
# ...                                                   ...         ...
# ORGANIZATION_TYPE_Industry: type 10                     0         0.0
# ORGANIZATION_TYPE_Industry: type 1                      0         0.0
# ORGANIZATION_TYPE_Housing                               0         0.0
# ORGANIZATION_TYPE_Hotel                                 0         0.0
# INSTAL_COUNT                                            0         0.0
#
# [446 rows x 2 columns]
